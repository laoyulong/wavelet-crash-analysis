# %% [markdown]
# # Wavelet Crash Exploration 2
# Notebook wrapper for `wavelet-crash-exploration_2.py`.
#
# Run the next cell to execute the full analysis and generate outputs.

# %%
# %run ./wavelet-crash-exploration_2.py
