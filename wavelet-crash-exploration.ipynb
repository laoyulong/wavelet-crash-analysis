# %% [markdown]
# # Wavelet Crash Exploration
# Notebook wrapper for `wavelet-crash-exploration.py`.
#
# Run the next cell to execute the full analysis and generate outputs.

# %%
# %run ./wavelet-crash-exploration.py
