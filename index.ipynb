# %% [markdown]
# # Binder Entry Notebook
#
# This project has multiple analysis notebooks. Use the links below to open each one.
#
# ## Notebooks
# - [Wavelet Crash Exploration](./wavelet-crash-exploration.ipynb)
# - [Wavelet Crash Exploration 2](./wavelet-crash-exploration_2.ipynb)
# - [Spatio-Temporal Grid Map Overlay](./wavelet-crash-spatio-temporal_grid-map-overlay.ipynb)
# - [Wavelet COI Spatial Demo](./wavelet_coi.ipynb)
#
# Tip: if links are not clickable in your environment, open the notebook files from the file browser panel.

# %%
import pathlib
for nb in sorted(pathlib.Path('.').glob('*.ipynb')):
    if nb.name != 'index.ipynb':
        print(nb.name)
